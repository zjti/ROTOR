# %%
import sys
import importlib

# %%
from glob import glob
glob('/drive/*')
# Out:
# ['/drive/ff',
#  '/drive/test.ipynb',
#  '/drive/a.txt',
#  '/drive/output_filename.zip.zip',
#  '/drive/crops',
#  '/drive/Untitled Folder2']

# %%
crops = importlib.import_module('/home/pyodide/crops')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 crops = importlib.import_module('/home/pyodide/crops')
#
# File /lib/python312.zip/importlib/__init__.py:90, in import_module(name, package)
#      88             break
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named '/home/pyodide/crops'

# %%
sys.path.append('/drive/')
sys.path
# Out:
# ['/home/pyodide',
#  '/lib/python312.zip',
#  '/lib/python3.12',
#  '/lib/python3.12/lib-dynload',
#  '',
#  '/lib/python3.12/site-packages',
#  '/drive/']

# %%
from crops import utils
# reload(utils)
utils.get_crop_dict()
# Out:
# <class 'crops.classes.ACK_BOHNE.ACK_BOHNE'> True
# <class 'crops.classes.SOJA.SOJA'> True
# <class 'crops.classes.WN_WEIZEN.WN_WEIZEN'> True

# %%
import crops

# %%
crops.crop_classes,dir(crops.classes)
# Out:
# ({},
#  ['__builtins__',
#   '__cached__',
#   '__doc__',
#   '__file__',
#   '__loader__',
#   '__name__',
#   '__package__',
#   '__path__',
#   '__spec__'])

# %% [raw]
# c
