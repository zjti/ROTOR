# %%
import shutil
shutil.make_archive('download', 'zip', '/home/pyodide')
# Out:
# '/drive/download.zip'

# %%
from glob import glob

# %%
glob('/drive/*')
# Out:
# ['/drive/Test_opts.ipynb',
#  '/drive/ff',
#  '/drive/a.txt',
#  '/drive/Test_crops.ipynb',
#  '/drive/download.zip',
#  '/drive/config.py',
#  '/drive/test123.py',
#  '/drive/README.ipynb',
#  '/drive/autoreload.py',
#  '/drive/lang.json',
#  '/drive/crops',
#  '/drive/Untitled Folder2']
